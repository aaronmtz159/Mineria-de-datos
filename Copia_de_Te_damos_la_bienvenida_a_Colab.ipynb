# %% [markdown]
# <a href="https://colab.research.google.com/github/aaronmtz159/Mineria-de-datos/blob/main/Copia_de_Te_damos_la_bienvenida_a_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mineria de datos

# %% [markdown]
# ##Primer Parcial

# %% [markdown]
# ###Introduccion

# %% [markdown]
# ####Conceptos

# %% [markdown]
# #### Understanding Data type Python

# %%
import numpy as np

# %%
#Arreglo lineal de enteros
np.array([1,4,2,5,3])

# %%
np.array([3,14,4,2,3])

# %%
np.array([1,2,3,4], dtype='float32')

# %%
np.array([1,2,3,4], dtype='int')

# %%
##Cuando el argumento de np.array es una iteracion anidada genera una matriz
np.array([range(i,i+3) for i in [2,4,6]])

# %% [markdown]
# ####Ciencia de datos

# %% [markdown]
# #### Python Magic Commands

# %%
##Sirve para evaluar el desempeño de la expresion en cuanto al tiempo
# %timeit L = [n ** 2 for n in range(1000)]

# %%
##Sirve para evaluar el desempeño de la expresion en cuanto al tiempo en mas de una linea

# %%timeit
L = []
for n in range(1000):
  L.append(n ** 2)

# %%
# !la
# Out:
# /bin/bash: line 1: la: command not found

# %%
# !pwd
# Out:
# /content

# %%
# !echo "printig from the shell"
# Out:
# printig from the shell

# %%
contents = !ls

# %%
print(contents)
# Out:
# ['sample_data']

# %%
directory = !pwd

# %%
print(directory)
# Out:
# ['/content']

# %%
type(directory)
# Out:
# IPython.utils.text.SList

# %%
message = "hello from python"

# %%
# !echo {message}
# Out:
# hello from python

# %%
# %ls
# Out:
# sample_data/

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %%
# %ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*

# %%
# %cat

# %% [markdown]
# #####Mineria de datos

# %% [markdown]
# Es una forma de extraer cierto tipo de datos

# %%
# La funcion help nos muestra
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
#Otra forma de obtener ayuda
len?

# %%
#Ejemplo de ayuda en lista
L = [1,2,3]
L.insert?

# %%
#Otro ejemplo de ayuda
L?

# %%
# Ejemplo con una funcion de dogString
def square(a):
  """Return the squeare of a."""
  return a ** 2

# %%
square?

# %%
square??

# %%
len??

# %%
L.
