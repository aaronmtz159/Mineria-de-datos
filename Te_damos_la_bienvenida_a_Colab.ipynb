# %% [markdown]
# <a href="https://colab.research.google.com/github/aaronmtz159/Mineria-de-datos/blob/main/Te_damos_la_bienvenida_a_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mineria de datos

# %% [markdown]
# ##Primer Parcial

# %% [markdown]
# ###Introduccion

# %% [markdown]
# ####Conceptos

# %% [markdown]
# ####Ciencia de datos

# %% [markdown]
# #####Mineria de datos

# %% [markdown]
# Es una forma de extraer cierto tipo de datos

# %%
# La funcion help nos muestra
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
#Otra forma de obtener ayuda
len?

# %%
#Ejemplo de ayuda en lista
L = [1,2,3]
L.insert?

# %%
#Otro ejemplo de ayuda
L?

# %%
# Ejemplo con una funcion de dogString
def square(a):
  """Return the squeare of a."""
  return a ** 2

# %%
square?

# %%
square??

# %%
len??

# %%
L.
