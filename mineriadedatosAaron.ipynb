# %% [markdown]
# <a href="https://colab.research.google.com/github/aaronmtz159/Mineria-de-datos/blob/main/mineriadedatosAaron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Mineria de datos

# %% [markdown]
# ##Primer Parcial

# %% [markdown]
# ###Introduccion

# %% [markdown]
# ####Conceptos

# %% [markdown]
# #####Mineria de datos

# %%
Es una forma de extraer cierto tipo de datos
